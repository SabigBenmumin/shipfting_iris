# %%
import os
import cv2
import time
import pandas as pd
from iris_module import read_image, HammingDistance, jaccard_distance_shifted, pearson_correlation_shifted

# %%
def get_flattened(tem1, tem2):
    hd_df = HammingDistance(template1=tem1, template2=tem2)
    jc_df = jaccard_distance_shifted(template1=tem1, template2=tem2)
    ps_df = pearson_correlation_shifted(template1=tem1, template2=tem2)
    flattened_data = pd.DataFrame([item for sublist in [hd_df[1], jc_df, ps_df] for item in sublist]).T
    return flattened_data

template1 = cv2.imread(f'Iris-Dataset/CASIA-IrisV2/device2/0000_template/0000_000.bmp', cv2.IMREAD_GRAYSCALE)
template2 = cv2.imread(f'Iris-Dataset/CASIA-IrisV2/device2/0000_template/0000_002.bmp', cv2.IMREAD_GRAYSCALE)
get_flattened(tem1=template1, tem2=template2)
# print(get_flattened(tem1=template1, tem2=template2))
# Out:
#          0        1        2         3         4         5         6   \
# 0  0.507227  0.50709  0.50582  0.505879  0.504707  0.504238  0.503535
#
#          7         8         9   ...        41        42        43        44  \
# 0  0.501953  0.382852  0.383125  ... -0.003952  0.234273  0.233726  0.205989
#
#          45      46        47        48       49        50
# 0  0.165985  0.1202  0.075195  0.027925 -0.01622 -0.054974
#
# [1 rows x 51 columns]

# %%
dataset_path = r"C:\Users\Sabig\Iris\shifting example\Iris-Dataset\CASIA-IrisV2\device2"

# %% [markdown]
# # Prepare Dataset Path

# %%
all_template_index = list()
for folder in os.listdir(dataset_path):
    for template in os.listdir(os.path.join(dataset_path, folder)):
        all_template_index.append([folder, template])
        last = (folder, template)
print(last)
print(len(all_template_index))
all_template_index
# Out:
# ('0059_template', '0059_019.bmp')
# 1200
# [['0000_template', '0000_000.bmp'],
#  ['0000_template', '0000_001.bmp'],
#  ['0000_template', '0000_002.bmp'],
#  ['0000_template', '0000_003.bmp'],
#  ['0000_template', '0000_004.bmp'],
#  ['0000_template', '0000_005.bmp'],
#  ['0000_template', '0000_006.bmp'],
#  ['0000_template', '0000_007.bmp'],
#  ['0000_template', '0000_008.bmp'],
#  ['0000_template', '0000_009.bmp'],
#  ['0000_template', '0000_010.bmp'],
#  ['0000_template', '0000_011.bmp'],
#  ['0000_template', '0000_012.bmp'],
#  ['0000_template', '0000_013.bmp'],
#  ['0000_template', '0000_014.bmp'],
#  ['0000_template', '0000_015.bmp'],
#  ['0000_template', '0000_016.bmp'],
#  ['0000_template', '0000_017.bmp'],
#  ['0000_template', '0000_018.bmp'],
#  ['0000_template', '0000_019.bmp'],
#  ['0001_template', '0001_000.bmp'],
#  ['0001_template', '0001_001.bmp'],
#  ['0001_template', '0001_002.bmp'],
#  ['0001_template', '0001_003.bmp'],
#  ['0001_template', '0001_004.bmp'],
#  ['0001_template', '0001_005.bmp'],
#  ['0001_template', '0001_006.bmp'],
#  ['0001_template', '0001_007.bmp'],
#  ['0001_template', '0001_008.bmp'],
#  ['0001_template', '0001_009.bmp'],
#  ['0001_template', '0001_010.bmp'],
#  ['0001_template', '0001_011.bmp'],
#  ['0001_template', '0001_012.bmp'],
#  ['0001_template', '0001_013.bmp'],
#  ['0001_template', '0001_014.bmp'],
#  ['0001_template', '0001_015.bmp'],
#  ['0001_template', '0001_016.bmp'],
#  ['0001_template', '0001_017.bmp'],
#  ['0001_template', '0001_018.bmp'],
#  ['0001_template', '0001_019.bmp'],
#  ['0002_template', '0002_000.bmp'],
#  ['0002_template', '0002_001.bmp'],
#  ['0002_template', '0002_002.bmp'],
#  ['0002_template', '0002_003.bmp'],
#  ['0002_template', '0002_004.bmp'],
#  ['0002_template', '0002_005.bmp'],
#  ['0002_template', '0002_006.bmp'],
#  ['0002_template', '0002_007.bmp'],
#  ['0002_template', '0002_008.bmp'],
#  ['0002_template', '0002_009.bmp'],
#  ['0002_template', '0002_010.bmp'],
#  ['0002_template', '0002_011.bmp'],
#  ['0002_template', '0002_012.bmp'],
#  ['0002_template', '0002_013.bmp'],
#  ['0002_template', '0002_014.bmp'],
#  ['0002_template', '0002_015.bmp'],
#  ['0002_template', '0002_016.bmp'],
#  ['0002_template', '0002_017.bmp'],
#  ['0002_template', '0002_018.bmp'],
#  ['0002_template', '0002_019.bmp'],
#  ['0003_template', '0003_000.bmp'],
#  ['0003_template', '0003_001.bmp'],
#  ['0003_template', '0003_002.bmp'],
#  ['0003_template', '0003_003.bmp'],
#  ['0003_template', '0003_004.bmp'],
#  ['0003_template', '0003_005.bmp'],
#  ['0003_template', '0003_006.bmp'],
#  ['0003_template', '0003_007.bmp'],
#  ['0003_template', '0003_008.bmp'],
#  ['0003_template', '0003_009.bmp'],
#  ['0003_template', '0003_010.bmp'],
#  ['0003_template', '0003_011.bmp'],
#  ['0003_template', '0003_012.bmp'],
#  ['0003_template', '0003_013.bmp'],
#  ['0003_template', '0003_014.bmp'],
#  ['0003_template', '0003_015.bmp'],
#  ['0003_template', '0003_016.bmp'],
#  ['0003_template', '0003_017.bmp'],
#  ['0003_template', '0003_018.bmp'],
#  ['0003_template', '0003_019.bmp'],
#  ['0004_template', '0004_000.bmp'],
#  ['0004_template', '0004_001.bmp'],
#  ['0004_template', '0004_002.bmp'],
#  ['0004_template', '0004_003.bmp'],
#  ['0004_template', '0004_004.bmp'],
#  ['0004_template', '0004_005.bmp'],
#  ['0004_template', '0004_006.bmp'],
#  ['0004_template', '0004_007.bmp'],
#  ['0004_template', '0004_008.bmp'],
#  ['0004_template', '0004_009.bmp'],
#  ['0004_template', '0004_010.bmp'],
#  ['0004_template', '0004_011.bmp'],
#  ['0004_template', '0004_012.bmp'],
#  ['0004_template', '0004_013.bmp'],
#  ['0004_template', '0004_014.bmp'],
#  ['0004_template', '0004_015.bmp'],
#  ['0004_template', '0004_016.bmp'],
#  ['0004_template', '0004_017.bmp'],
#  ['0004_template', '0004_018.bmp'],
#  ['0004_template', '0004_019.bmp'],
#  ['0005_template', '0005_000.bmp'],
#  ['0005_template', '0005_001.bmp'],
#  ['0005_template', '0005_002.bmp'],
#  ['0005_template', '0005_003.bmp'],
#  ['0005_template', '0005_004.bmp'],
#  ['0005_template', '0005_005.bmp'],
#  ['0005_template', '0005_006.bmp'],
#  ['0005_template', '0005_007.bmp'],
#  ['0005_template', '0005_008.bmp'],
#  ['0005_template', '0005_009.bmp'],
#  ['0005_template', '0005_010.bmp'],
#  ['0005_template', '0005_011.bmp'],
#  ['0005_template', '0005_012.bmp'],
#  ['0005_template', '0005_013.bmp'],
#  ['0005_template', '0005_014.bmp'],
#  ['0005_template', '0005_015.bmp'],
#  ['0005_template', '0005_016.bmp'],
#  ['0005_template', '0005_017.bmp'],
#  ['0005_template', '0005_018.bmp'],
#  ['0005_template', '0005_019.bmp'],
#  ['0006_template', '0006_000.bmp'],
#  ['0006_template', '0006_001.bmp'],
#  ['0006_template', '0006_002.bmp'],
#  ['0006_template', '0006_003.bmp'],
#  ['0006_template', '0006_004.bmp'],
#  ['0006_template', '0006_005.bmp'],
#  ['0006_template', '0006_006.bmp'],
#  ['0006_template', '0006_007.bmp'],
#  ['0006_template', '0006_008.bmp'],
#  ['0006_template', '0006_009.bmp'],
#  ['0006_template', '0006_010.bmp'],
#  ['0006_template', '0006_011.bmp'],
#  ['0006_template', '0006_012.bmp'],
#  ['0006_template', '0006_013.bmp'],
#  ['0006_template', '0006_014.bmp'],
#  ['0006_template', '0006_015.bmp'],
#  ['0006_template', '0006_016.bmp'],
#  ['0006_template', '0006_017.bmp'],
#  ['0006_template', '0006_018.bmp'],
#  ['0006_template', '0006_019.bmp'],
#  ['0007_template', '0007_000.bmp'],
#  ['0007_template', '0007_001.bmp'],
#  ['0007_template', '0007_002.bmp'],
#  ['0007_template', '0007_003.bmp'],
#  ['0007_template', '0007_004.bmp'],
#  ['0007_template', '0007_005.bmp'],
#  ['0007_template', '0007_006.bmp'],
#  ['0007_template', '0007_007.bmp'],
#  ['0007_template', '0007_008.bmp'],
#  ['0007_template', '0007_009.bmp'],
#  ['0007_template', '0007_010.bmp'],
#  ['0007_template', '0007_011.bmp'],
#  ['0007_template', '0007_012.bmp'],
#  ['0007_template', '0007_013.bmp'],
#  ['0007_template', '0007_014.bmp'],
#  ['0007_template', '0007_015.bmp'],
#  ['0007_template', '0007_016.bmp'],
#  ['0007_template', '0007_017.bmp'],
#  ['0007_template', '0007_018.bmp'],
#  ['0007_template', '0007_019.bmp'],
#  ['0008_template', '0008_000.bmp'],
#  ['0008_template', '0008_001.bmp'],
#  ['0008_template', '0008_002.bmp'],
#  ['0008_template', '0008_003.bmp'],
#  ['0008_template', '0008_004.bmp'],
#  ['0008_template', '0008_005.bmp'],
#  ['0008_template', '0008_006.bmp'],
#  ['0008_template', '0008_007.bmp'],
#  ['0008_template', '0008_008.bmp'],
#  ['0008_template', '0008_009.bmp'],
#  ['0008_template', '0008_010.bmp'],
#  ['0008_template', '0008_011.bmp'],
#  ['0008_template', '0008_012.bmp'],
#  ['0008_template', '0008_013.bmp'],
#  ['0008_template', '0008_014.bmp'],
#  ['0008_template', '0008_015.bmp'],
#  ['0008_template', '0008_016.bmp'],
#  ['0008_template', '0008_017.bmp'],
#  ['0008_template', '0008_018.bmp'],
#  ['0008_template', '0008_019.bmp'],
#  ['0009_template', '0009_000.bmp'],
#  ['0009_template', '0009_001.bmp'],
#  ['0009_template', '0009_002.bmp'],
#  ['0009_template', '0009_003.bmp'],
#  ['0009_template', '0009_004.bmp'],
#  ['0009_template', '0009_005.bmp'],
#  ['0009_template', '0009_006.bmp'],
#  ['0009_template', '0009_007.bmp'],
#  ['0009_template', '0009_008.bmp'],
#  ['0009_template', '0009_009.bmp'],
#  ['0009_template', '0009_010.bmp'],
#  ['0009_template', '0009_011.bmp'],
#  ['0009_template', '0009_012.bmp'],
#  ['0009_template', '0009_013.bmp'],
#  ['0009_template', '0009_014.bmp'],
#  ['0009_template', '0009_015.bmp'],
#  ['0009_template', '0009_016.bmp'],
#  ['0009_template', '0009_017.bmp'],
#  ['0009_template', '0009_018.bmp'],
#  ['0009_template', '0009_019.bmp'],
#  ['0010_template', '0010_000.bmp'],
#  ['0010_template', '0010_001.bmp'],
#  ['0010_template', '0010_002.bmp'],
#  ['0010_template', '0010_003.bmp'],
#  ['0010_template', '0010_004.bmp'],
#  ['0010_template', '0010_005.bmp'],
#  ['0010_template', '0010_006.bmp'],
#  ['0010_template', '0010_007.bmp'],
#  ['0010_template', '0010_008.bmp'],
#  ['0010_template', '0010_009.bmp'],
#  ['0010_template', '0010_010.bmp'],
#  ['0010_template', '0010_011.bmp'],
#  ['0010_template', '0010_012.bmp'],
#  ['0010_template', '0010_013.bmp'],
#  ['0010_template', '0010_014.bmp'],
#  ['0010_template', '0010_015.bmp'],
#  ['0010_template', '0010_016.bmp'],
#  ['0010_template', '0010_017.bmp'],
#  ['0010_template', '0010_018.bmp'],
#  ['0010_template', '0010_019.bmp'],
#  ['0011_template', '0011_000.bmp'],
#  ['0011_template', '0011_001.bmp'],
#  ['0011_template', '0011_002.bmp'],
#  ['0011_template', '0011_003.bmp'],
#  ['0011_template', '0011_004.bmp'],
#  ['0011_template', '0011_005.bmp'],
#  ['0011_template', '0011_006.bmp'],
#  ['0011_template', '0011_007.bmp'],
#  ['0011_template', '0011_008.bmp'],
#  ['0011_template', '0011_009.bmp'],
#  ['0011_template', '0011_010.bmp'],
#  ['0011_template', '0011_011.bmp'],
#  ['0011_template', '0011_012.bmp'],
#  ['0011_template', '0011_013.bmp'],
#  ['0011_template', '0011_014.bmp'],
#  ['0011_template', '0011_015.bmp'],
#  ['0011_template', '0011_016.bmp'],
#  ['0011_template', '0011_017.bmp'],
#  ['0011_template', '0011_018.bmp'],
#  ['0011_template', '0011_019.bmp'],
#  ['0012_template', '0012_000.bmp'],
#  ['0012_template', '0012_001.bmp'],
#  ['0012_template', '0012_002.bmp'],
#  ['0012_template', '0012_003.bmp'],
#  ['0012_template', '0012_004.bmp'],
#  ['0012_template', '0012_005.bmp'],
#  ['0012_template', '0012_006.bmp'],
#  ['0012_template', '0012_007.bmp'],
#  ['0012_template', '0012_008.bmp'],
#  ['0012_template', '0012_009.bmp'],
#  ['0012_template', '0012_010.bmp'],
#  ['0012_template', '0012_011.bmp'],
#  ['0012_template', '0012_012.bmp'],
#  ['0012_template', '0012_013.bmp'],
#  ['0012_template', '0012_014.bmp'],
#  ['0012_template', '0012_015.bmp'],
#  ['0012_template', '0012_016.bmp'],
#  ['0012_template', '0012_017.bmp'],
#  ['0012_template', '0012_018.bmp'],
#  ['0012_template', '0012_019.bmp'],
#  ['0013_template', '0013_000.bmp'],
#  ['0013_template', '0013_001.bmp'],
#  ['0013_template', '0013_002.bmp'],
#  ['0013_template', '0013_003.bmp'],
#  ['0013_template', '0013_004.bmp'],
#  ['0013_template', '0013_005.bmp'],
#  ['0013_template', '0013_006.bmp'],
#  ['0013_template', '0013_007.bmp'],
#  ['0013_template', '0013_008.bmp'],
#  ['0013_template', '0013_009.bmp'],
#  ['0013_template', '0013_010.bmp'],
#  ['0013_template', '0013_011.bmp'],
#  ['0013_template', '0013_012.bmp'],
#  ['0013_template', '0013_013.bmp'],
#  ['0013_template', '0013_014.bmp'],
#  ['0013_template', '0013_015.bmp'],
#  ['0013_template', '0013_016.bmp'],
#  ['0013_template', '0013_017.bmp'],
#  ['0013_template', '0013_018.bmp'],
#  ['0013_template', '0013_019.bmp'],
#  ['0014_template', '0014_000.bmp'],
#  ['0014_template', '0014_001.bmp'],
#  ['0014_template', '0014_002.bmp'],
#  ['0014_template', '0014_003.bmp'],
#  ['0014_template', '0014_004.bmp'],
#  ['0014_template', '0014_005.bmp'],
#  ['0014_template', '0014_006.bmp'],
#  ['0014_template', '0014_007.bmp'],
#  ['0014_template', '0014_008.bmp'],
#  ['0014_template', '0014_009.bmp'],
#  ['0014_template', '0014_010.bmp'],
#  ['0014_template', '0014_011.bmp'],
#  ['0014_template', '0014_012.bmp'],
#  ['0014_template', '0014_013.bmp'],
#  ['0014_template', '0014_014.bmp'],
#  ['0014_template', '0014_015.bmp'],
#  ['0014_template', '0014_016.bmp'],
#  ['0014_template', '0014_017.bmp'],
#  ['0014_template', '0014_018.bmp'],
#  ['0014_template', '0014_019.bmp'],
#  ['0015_template', '0015_000.bmp'],
#  ['0015_template', '0015_001.bmp'],
#  ['0015_template', '0015_002.bmp'],
#  ['0015_template', '0015_003.bmp'],
#  ['0015_template', '0015_004.bmp'],
#  ['0015_template', '0015_005.bmp'],
#  ['0015_template', '0015_006.bmp'],
#  ['0015_template', '0015_007.bmp'],
#  ['0015_template', '0015_008.bmp'],
#  ['0015_template', '0015_009.bmp'],
#  ['0015_template', '0015_010.bmp'],
#  ['0015_template', '0015_011.bmp'],
#  ['0015_template', '0015_012.bmp'],
#  ['0015_template', '0015_013.bmp'],
#  ['0015_template', '0015_014.bmp'],
#  ['0015_template', '0015_015.bmp'],
#  ['0015_template', '0015_016.bmp'],
#  ['0015_template', '0015_017.bmp'],
#  ['0015_template', '0015_018.bmp'],
#  ['0015_template', '0015_019.bmp'],
#  ['0016_template', '0016_000.bmp'],
#  ['0016_template', '0016_001.bmp'],
#  ['0016_template', '0016_002.bmp'],
#  ['0016_template', '0016_003.bmp'],
#  ['0016_template', '0016_004.bmp'],
#  ['0016_template', '0016_005.bmp'],
#  ['0016_template', '0016_006.bmp'],
#  ['0016_template', '0016_007.bmp'],
#  ['0016_template', '0016_008.bmp'],
#  ['0016_template', '0016_009.bmp'],
#  ['0016_template', '0016_010.bmp'],
#  ['0016_template', '0016_011.bmp'],
#  ['0016_template', '0016_012.bmp'],
#  ['0016_template', '0016_013.bmp'],
#  ['0016_template', '0016_014.bmp'],
#  ['0016_template', '0016_015.bmp'],
#  ['0016_template', '0016_016.bmp'],
#  ['0016_template', '0016_017.bmp'],
#  ['0016_template', '0016_018.bmp'],
#  ['0016_template', '0016_019.bmp'],
#  ['0017_template', '0017_000.bmp'],
#  ['0017_template', '0017_001.bmp'],
#  ['0017_template', '0017_002.bmp'],
#  ['0017_template', '0017_003.bmp'],
#  ['0017_template', '0017_004.bmp'],
#  ['0017_template', '0017_005.bmp'],
#  ['0017_template', '0017_006.bmp'],
#  ['0017_template', '0017_007.bmp'],
#  ['0017_template', '0017_008.bmp'],
#  ['0017_template', '0017_009.bmp'],
#  ['0017_template', '0017_010.bmp'],
#  ['0017_template', '0017_011.bmp'],
#  ['0017_template', '0017_012.bmp'],
#  ['0017_template', '0017_013.bmp'],
#  ['0017_template', '0017_014.bmp'],
#  ['0017_template', '0017_015.bmp'],
#  ['0017_template', '0017_016.bmp'],
#  ['0017_template', '0017_017.bmp'],
#  ['0017_template', '0017_018.bmp'],
#  ['0017_template', '0017_019.bmp'],
#  ['0018_template', '0018_000.bmp'],
#  ['0018_template', '0018_001.bmp'],
#  ['0018_template', '0018_002.bmp'],
#  ['0018_template', '0018_003.bmp'],
#  ['0018_template', '0018_004.bmp'],
#  ['0018_template', '0018_005.bmp'],
#  ['0018_template', '0018_006.bmp'],
#  ['0018_template', '0018_007.bmp'],
#  ['0018_template', '0018_008.bmp'],
#  ['0018_template', '0018_009.bmp'],
#  ['0018_template', '0018_010.bmp'],
#  ['0018_template', '0018_011.bmp'],
#  ['0018_template', '0018_012.bmp'],
#  ['0018_template', '0018_013.bmp'],
#  ['0018_template', '0018_014.bmp'],
#  ['0018_template', '0018_015.bmp'],
#  ['0018_template', '0018_016.bmp'],
#  ['0018_template', '0018_017.bmp'],
#  ['0018_template', '0018_018.bmp'],
#  ['0018_template', '0018_019.bmp'],
#  ['0019_template', '0019_000.bmp'],
#  ['0019_template', '0019_001.bmp'],
#  ['0019_template', '0019_002.bmp'],
#  ['0019_template', '0019_003.bmp'],
#  ['0019_template', '0019_004.bmp'],
#  ['0019_template', '0019_005.bmp'],
#  ['0019_template', '0019_006.bmp'],
#  ['0019_template', '0019_007.bmp'],
#  ['0019_template', '0019_008.bmp'],
#  ['0019_template', '0019_009.bmp'],
#  ['0019_template', '0019_010.bmp'],
#  ['0019_template', '0019_011.bmp'],
#  ['0019_template', '0019_012.bmp'],
#  ['0019_template', '0019_013.bmp'],
#  ['0019_template', '0019_014.bmp'],
#  ['0019_template', '0019_015.bmp'],
#  ['0019_template', '0019_016.bmp'],
#  ['0019_template', '0019_017.bmp'],
#  ['0019_template', '0019_018.bmp'],
#  ['0019_template', '0019_019.bmp'],
#  ['0020_template', '0020_000.bmp'],
#  ['0020_template', '0020_001.bmp'],
#  ['0020_template', '0020_002.bmp'],
#  ['0020_template', '0020_003.bmp'],
#  ['0020_template', '0020_004.bmp'],
#  ['0020_template', '0020_005.bmp'],
#  ['0020_template', '0020_006.bmp'],
#  ['0020_template', '0020_007.bmp'],
#  ['0020_template', '0020_008.bmp'],
#  ['0020_template', '0020_009.bmp'],
#  ['0020_template', '0020_010.bmp'],
#  ['0020_template', '0020_011.bmp'],
#  ['0020_template', '0020_012.bmp'],
#  ['0020_template', '0020_013.bmp'],
#  ['0020_template', '0020_014.bmp'],
#  ['0020_template', '0020_015.bmp'],
#  ['0020_template', '0020_016.bmp'],
#  ['0020_template', '0020_017.bmp'],
#  ['0020_template', '0020_018.bmp'],
#  ['0020_template', '0020_019.bmp'],
#  ['0021_template', '0021_000.bmp'],
#  ['0021_template', '0021_001.bmp'],
#  ['0021_template', '0021_002.bmp'],
#  ['0021_template', '0021_003.bmp'],
#  ['0021_template', '0021_004.bmp'],
#  ['0021_template', '0021_005.bmp'],
#  ['0021_template', '0021_006.bmp'],
#  ['0021_template', '0021_007.bmp'],
#  ['0021_template', '0021_008.bmp'],
#  ['0021_template', '0021_009.bmp'],
#  ['0021_template', '0021_010.bmp'],
#  ['0021_template', '0021_011.bmp'],
#  ['0021_template', '0021_012.bmp'],
#  ['0021_template', '0021_013.bmp'],
#  ['0021_template', '0021_014.bmp'],
#  ['0021_template', '0021_015.bmp'],
#  ['0021_template', '0021_016.bmp'],
#  ['0021_template', '0021_017.bmp'],
#  ['0021_template', '0021_018.bmp'],
#  ['0021_template', '0021_019.bmp'],
#  ['0022_template', '0022_000.bmp'],
#  ['0022_template', '0022_001.bmp'],
#  ['0022_template', '0022_002.bmp'],
#  ['0022_template', '0022_003.bmp'],
#  ['0022_template', '0022_004.bmp'],
#  ['0022_template', '0022_005.bmp'],
#  ['0022_template', '0022_006.bmp'],
#  ['0022_template', '0022_007.bmp'],
#  ['0022_template', '0022_008.bmp'],
#  ['0022_template', '0022_009.bmp'],
#  ['0022_template', '0022_010.bmp'],
#  ['0022_template', '0022_011.bmp'],
#  ['0022_template', '0022_012.bmp'],
#  ['0022_template', '0022_013.bmp'],
#  ['0022_template', '0022_014.bmp'],
#  ['0022_template', '0022_015.bmp'],
#  ['0022_template', '0022_016.bmp'],
#  ['0022_template', '0022_017.bmp'],
#  ['0022_template', '0022_018.bmp'],
#  ['0022_template', '0022_019.bmp'],
#  ['0023_template', '0023_000.bmp'],
#  ['0023_template', '0023_001.bmp'],
#  ['0023_template', '0023_002.bmp'],
#  ['0023_template', '0023_003.bmp'],
#  ['0023_template', '0023_004.bmp'],
#  ['0023_template', '0023_005.bmp'],
#  ['0023_template', '0023_006.bmp'],
#  ['0023_template', '0023_007.bmp'],
#  ['0023_template', '0023_008.bmp'],
#  ['0023_template', '0023_009.bmp'],
#  ['0023_template', '0023_010.bmp'],
#  ['0023_template', '0023_011.bmp'],
#  ['0023_template', '0023_012.bmp'],
#  ['0023_template', '0023_013.bmp'],
#  ['0023_template', '0023_014.bmp'],
#  ['0023_template', '0023_015.bmp'],
#  ['0023_template', '0023_016.bmp'],
#  ['0023_template', '0023_017.bmp'],
#  ['0023_template', '0023_018.bmp'],
#  ['0023_template', '0023_019.bmp'],
#  ['0024_template', '0024_000.bmp'],
#  ['0024_template', '0024_001.bmp'],
#  ['0024_template', '0024_002.bmp'],
#  ['0024_template', '0024_003.bmp'],
#  ['0024_template', '0024_004.bmp'],
#  ['0024_template', '0024_005.bmp'],
#  ['0024_template', '0024_006.bmp'],
#  ['0024_template', '0024_007.bmp'],
#  ['0024_template', '0024_008.bmp'],
#  ['0024_template', '0024_009.bmp'],
#  ['0024_template', '0024_010.bmp'],
#  ['0024_template', '0024_011.bmp'],
#  ['0024_template', '0024_012.bmp'],
#  ['0024_template', '0024_013.bmp'],
#  ['0024_template', '0024_014.bmp'],
#  ['0024_template', '0024_015.bmp'],
#  ['0024_template', '0024_016.bmp'],
#  ['0024_template', '0024_017.bmp'],
#  ['0024_template', '0024_018.bmp'],
#  ['0024_template', '0024_019.bmp'],
#  ['0025_template', '0025_000.bmp'],
#  ['0025_template', '0025_001.bmp'],
#  ['0025_template', '0025_002.bmp'],
#  ['0025_template', '0025_003.bmp'],
#  ['0025_template', '0025_004.bmp'],
#  ['0025_template', '0025_005.bmp'],
#  ['0025_template', '0025_006.bmp'],
#  ['0025_template', '0025_007.bmp'],
#  ['0025_template', '0025_008.bmp'],
#  ['0025_template', '0025_009.bmp'],
#  ['0025_template', '0025_010.bmp'],
#  ['0025_template', '0025_011.bmp'],
#  ['0025_template', '0025_012.bmp'],
#  ['0025_template', '0025_013.bmp'],
#  ['0025_template', '0025_014.bmp'],
#  ['0025_template', '0025_015.bmp'],
#  ['0025_template', '0025_016.bmp'],
#  ['0025_template', '0025_017.bmp'],
#  ['0025_template', '0025_018.bmp'],
#  ['0025_template', '0025_019.bmp'],
#  ['0026_template', '0026_000.bmp'],
#  ['0026_template', '0026_001.bmp'],
#  ['0026_template', '0026_002.bmp'],
#  ['0026_template', '0026_003.bmp'],
#  ['0026_template', '0026_004.bmp'],
#  ['0026_template', '0026_005.bmp'],
#  ['0026_template', '0026_006.bmp'],
#  ['0026_template', '0026_007.bmp'],
#  ['0026_template', '0026_008.bmp'],
#  ['0026_template', '0026_009.bmp'],
#  ['0026_template', '0026_010.bmp'],
#  ['0026_template', '0026_011.bmp'],
#  ['0026_template', '0026_012.bmp'],
#  ['0026_template', '0026_013.bmp'],
#  ['0026_template', '0026_014.bmp'],
#  ['0026_template', '0026_015.bmp'],
#  ['0026_template', '0026_016.bmp'],
#  ['0026_template', '0026_017.bmp'],
#  ['0026_template', '0026_018.bmp'],
#  ['0026_template', '0026_019.bmp'],
#  ['0027_template', '0027_000.bmp'],
#  ['0027_template', '0027_001.bmp'],
#  ['0027_template', '0027_002.bmp'],
#  ['0027_template', '0027_003.bmp'],
#  ['0027_template', '0027_004.bmp'],
#  ['0027_template', '0027_005.bmp'],
#  ['0027_template', '0027_006.bmp'],
#  ['0027_template', '0027_007.bmp'],
#  ['0027_template', '0027_008.bmp'],
#  ['0027_template', '0027_009.bmp'],
#  ['0027_template', '0027_010.bmp'],
#  ['0027_template', '0027_011.bmp'],
#  ['0027_template', '0027_012.bmp'],
#  ['0027_template', '0027_013.bmp'],
#  ['0027_template', '0027_014.bmp'],
#  ['0027_template', '0027_015.bmp'],
#  ['0027_template', '0027_016.bmp'],
#  ['0027_template', '0027_017.bmp'],
#  ['0027_template', '0027_018.bmp'],
#  ['0027_template', '0027_019.bmp'],
#  ['0028_template', '0028_000.bmp'],
#  ['0028_template', '0028_001.bmp'],
#  ['0028_template', '0028_002.bmp'],
#  ['0028_template', '0028_003.bmp'],
#  ['0028_template', '0028_004.bmp'],
#  ['0028_template', '0028_005.bmp'],
#  ['0028_template', '0028_006.bmp'],
#  ['0028_template', '0028_007.bmp'],
#  ['0028_template', '0028_008.bmp'],
#  ['0028_template', '0028_009.bmp'],
#  ['0028_template', '0028_010.bmp'],
#  ['0028_template', '0028_011.bmp'],
#  ['0028_template', '0028_012.bmp'],
#  ['0028_template', '0028_013.bmp'],
#  ['0028_template', '0028_014.bmp'],
#  ['0028_template', '0028_015.bmp'],
#  ['0028_template', '0028_016.bmp'],
#  ['0028_template', '0028_017.bmp'],
#  ['0028_template', '0028_018.bmp'],
#  ['0028_template', '0028_019.bmp'],
#  ['0029_template', '0029_000.bmp'],
#  ['0029_template', '0029_001.bmp'],
#  ['0029_template', '0029_002.bmp'],
#  ['0029_template', '0029_003.bmp'],
#  ['0029_template', '0029_004.bmp'],
#  ['0029_template', '0029_005.bmp'],
#  ['0029_template', '0029_006.bmp'],
#  ['0029_template', '0029_007.bmp'],
#  ['0029_template', '0029_008.bmp'],
#  ['0029_template', '0029_009.bmp'],
#  ['0029_template', '0029_010.bmp'],
#  ['0029_template', '0029_011.bmp'],
#  ['0029_template', '0029_012.bmp'],
#  ['0029_template', '0029_013.bmp'],
#  ['0029_template', '0029_014.bmp'],
#  ['0029_template', '0029_015.bmp'],
#  ['0029_template', '0029_016.bmp'],
#  ['0029_template', '0029_017.bmp'],
#  ['0029_template', '0029_018.bmp'],
#  ['0029_template', '0029_019.bmp'],
#  ['0030_template', '0030_000.bmp'],
#  ['0030_template', '0030_001.bmp'],
#  ['0030_template', '0030_002.bmp'],
#  ['0030_template', '0030_003.bmp'],
#  ['0030_template', '0030_004.bmp'],
#  ['0030_template', '0030_005.bmp'],
#  ['0030_template', '0030_006.bmp'],
#  ['0030_template', '0030_007.bmp'],
#  ['0030_template', '0030_008.bmp'],
#  ['0030_template', '0030_009.bmp'],
#  ['0030_template', '0030_010.bmp'],
#  ['0030_template', '0030_011.bmp'],
#  ['0030_template', '0030_012.bmp'],
#  ['0030_template', '0030_013.bmp'],
#  ['0030_template', '0030_014.bmp'],
#  ['0030_template', '0030_015.bmp'],
#  ['0030_template', '0030_016.bmp'],
#  ['0030_template', '0030_017.bmp'],
#  ['0030_template', '0030_018.bmp'],
#  ['0030_template', '0030_019.bmp'],
#  ['0031_template', '0031_000.bmp'],
#  ['0031_template', '0031_001.bmp'],
#  ['0031_template', '0031_002.bmp'],
#  ['0031_template', '0031_003.bmp'],
#  ['0031_template', '0031_004.bmp'],
#  ['0031_template', '0031_005.bmp'],
#  ['0031_template', '0031_006.bmp'],
#  ['0031_template', '0031_007.bmp'],
#  ['0031_template', '0031_008.bmp'],
#  ['0031_template', '0031_009.bmp'],
#  ['0031_template', '0031_010.bmp'],
#  ['0031_template', '0031_011.bmp'],
#  ['0031_template', '0031_012.bmp'],
#  ['0031_template', '0031_013.bmp'],
#  ['0031_template', '0031_014.bmp'],
#  ['0031_template', '0031_015.bmp'],
#  ['0031_template', '0031_016.bmp'],
#  ['0031_template', '0031_017.bmp'],
#  ['0031_template', '0031_018.bmp'],
#  ['0031_template', '0031_019.bmp'],
#  ['0032_template', '0032_000.bmp'],
#  ['0032_template', '0032_001.bmp'],
#  ['0032_template', '0032_002.bmp'],
#  ['0032_template', '0032_003.bmp'],
#  ['0032_template', '0032_004.bmp'],
#  ['0032_template', '0032_005.bmp'],
#  ['0032_template', '0032_006.bmp'],
#  ['0032_template', '0032_007.bmp'],
#  ['0032_template', '0032_008.bmp'],
#  ['0032_template', '0032_009.bmp'],
#  ['0032_template', '0032_010.bmp'],
#  ['0032_template', '0032_011.bmp'],
#  ['0032_template', '0032_012.bmp'],
#  ['0032_template', '0032_013.bmp'],
#  ['0032_template', '0032_014.bmp'],
#  ['0032_template', '0032_015.bmp'],
#  ['0032_template', '0032_016.bmp'],
#  ['0032_template', '0032_017.bmp'],
#  ['0032_template', '0032_018.bmp'],
#  ['0032_template', '0032_019.bmp'],
#  ['0033_template', '0033_000.bmp'],
#  ['0033_template', '0033_001.bmp'],
#  ['0033_template', '0033_002.bmp'],
#  ['0033_template', '0033_003.bmp'],
#  ['0033_template', '0033_004.bmp'],
#  ['0033_template', '0033_005.bmp'],
#  ['0033_template', '0033_006.bmp'],
#  ['0033_template', '0033_007.bmp'],
#  ['0033_template', '0033_008.bmp'],
#  ['0033_template', '0033_009.bmp'],
#  ['0033_template', '0033_010.bmp'],
#  ['0033_template', '0033_011.bmp'],
#  ['0033_template', '0033_012.bmp'],
#  ['0033_template', '0033_013.bmp'],
#  ['0033_template', '0033_014.bmp'],
#  ['0033_template', '0033_015.bmp'],
#  ['0033_template', '0033_016.bmp'],
#  ['0033_template', '0033_017.bmp'],
#  ['0033_template', '0033_018.bmp'],
#  ['0033_template', '0033_019.bmp'],
#  ['0034_template', '0034_000.bmp'],
#  ['0034_template', '0034_001.bmp'],
#  ['0034_template', '0034_002.bmp'],
#  ['0034_template', '0034_003.bmp'],
#  ['0034_template', '0034_004.bmp'],
#  ['0034_template', '0034_005.bmp'],
#  ['0034_template', '0034_006.bmp'],
#  ['0034_template', '0034_007.bmp'],
#  ['0034_template', '0034_008.bmp'],
#  ['0034_template', '0034_009.bmp'],
#  ['0034_template', '0034_010.bmp'],
#  ['0034_template', '0034_011.bmp'],
#  ['0034_template', '0034_012.bmp'],
#  ['0034_template', '0034_013.bmp'],
#  ['0034_template', '0034_014.bmp'],
#  ['0034_template', '0034_015.bmp'],
#  ['0034_template', '0034_016.bmp'],
#  ['0034_template', '0034_017.bmp'],
#  ['0034_template', '0034_018.bmp'],
#  ['0034_template', '0034_019.bmp'],
#  ['0035_template', '0035_000.bmp'],
#  ['0035_template', '0035_001.bmp'],
#  ['0035_template', '0035_002.bmp'],
#  ['0035_template', '0035_003.bmp'],
#  ['0035_template', '0035_004.bmp'],
#  ['0035_template', '0035_005.bmp'],
#  ['0035_template', '0035_006.bmp'],
#  ['0035_template', '0035_007.bmp'],
#  ['0035_template', '0035_008.bmp'],
#  ['0035_template', '0035_009.bmp'],
#  ['0035_template', '0035_010.bmp'],
#  ['0035_template', '0035_011.bmp'],
#  ['0035_template', '0035_012.bmp'],
#  ['0035_template', '0035_013.bmp'],
#  ['0035_template', '0035_014.bmp'],
#  ['0035_template', '0035_015.bmp'],
#  ['0035_template', '0035_016.bmp'],
#  ['0035_template', '0035_017.bmp'],
#  ['0035_template', '0035_018.bmp'],
#  ['0035_template', '0035_019.bmp'],
#  ['0036_template', '0036_000.bmp'],
#  ['0036_template', '0036_001.bmp'],
#  ['0036_template', '0036_002.bmp'],
#  ['0036_template', '0036_003.bmp'],
#  ['0036_template', '0036_004.bmp'],
#  ['0036_template', '0036_005.bmp'],
#  ['0036_template', '0036_006.bmp'],
#  ['0036_template', '0036_007.bmp'],
#  ['0036_template', '0036_008.bmp'],
#  ['0036_template', '0036_009.bmp'],
#  ['0036_template', '0036_010.bmp'],
#  ['0036_template', '0036_011.bmp'],
#  ['0036_template', '0036_012.bmp'],
#  ['0036_template', '0036_013.bmp'],
#  ['0036_template', '0036_014.bmp'],
#  ['0036_template', '0036_015.bmp'],
#  ['0036_template', '0036_016.bmp'],
#  ['0036_template', '0036_017.bmp'],
#  ['0036_template', '0036_018.bmp'],
#  ['0036_template', '0036_019.bmp'],
#  ['0037_template', '0037_000.bmp'],
#  ['0037_template', '0037_001.bmp'],
#  ['0037_template', '0037_002.bmp'],
#  ['0037_template', '0037_003.bmp'],
#  ['0037_template', '0037_004.bmp'],
#  ['0037_template', '0037_005.bmp'],
#  ['0037_template', '0037_006.bmp'],
#  ['0037_template', '0037_007.bmp'],
#  ['0037_template', '0037_008.bmp'],
#  ['0037_template', '0037_009.bmp'],
#  ['0037_template', '0037_010.bmp'],
#  ['0037_template', '0037_011.bmp'],
#  ['0037_template', '0037_012.bmp'],
#  ['0037_template', '0037_013.bmp'],
#  ['0037_template', '0037_014.bmp'],
#  ['0037_template', '0037_015.bmp'],
#  ['0037_template', '0037_016.bmp'],
#  ['0037_template', '0037_017.bmp'],
#  ['0037_template', '0037_018.bmp'],
#  ['0037_template', '0037_019.bmp'],
#  ['0038_template', '0038_000.bmp'],
#  ['0038_template', '0038_001.bmp'],
#  ['0038_template', '0038_002.bmp'],
#  ['0038_template', '0038_003.bmp'],
#  ['0038_template', '0038_004.bmp'],
#  ['0038_template', '0038_005.bmp'],
#  ['0038_template', '0038_006.bmp'],
#  ['0038_template', '0038_007.bmp'],
#  ['0038_template', '0038_008.bmp'],
#  ['0038_template', '0038_009.bmp'],
#  ['0038_template', '0038_010.bmp'],
#  ['0038_template', '0038_011.bmp'],
#  ['0038_template', '0038_012.bmp'],
#  ['0038_template', '0038_013.bmp'],
#  ['0038_template', '0038_014.bmp'],
#  ['0038_template', '0038_015.bmp'],
#  ['0038_template', '0038_016.bmp'],
#  ['0038_template', '0038_017.bmp'],
#  ['0038_template', '0038_018.bmp'],
#  ['0038_template', '0038_019.bmp'],
#  ['0039_template', '0039_000.bmp'],
#  ['0039_template', '0039_001.bmp'],
#  ['0039_template', '0039_002.bmp'],
#  ['0039_template', '0039_003.bmp'],
#  ['0039_template', '0039_004.bmp'],
#  ['0039_template', '0039_005.bmp'],
#  ['0039_template', '0039_006.bmp'],
#  ['0039_template', '0039_007.bmp'],
#  ['0039_template', '0039_008.bmp'],
#  ['0039_template', '0039_009.bmp'],
#  ['0039_template', '0039_010.bmp'],
#  ['0039_template', '0039_011.bmp'],
#  ['0039_template', '0039_012.bmp'],
#  ['0039_template', '0039_013.bmp'],
#  ['0039_template', '0039_014.bmp'],
#  ['0039_template', '0039_015.bmp'],
#  ['0039_template', '0039_016.bmp'],
#  ['0039_template', '0039_017.bmp'],
#  ['0039_template', '0039_018.bmp'],
#  ['0039_template', '0039_019.bmp'],
#  ['0040_template', '0040_000.bmp'],
#  ['0040_template', '0040_001.bmp'],
#  ['0040_template', '0040_002.bmp'],
#  ['0040_template', '0040_003.bmp'],
#  ['0040_template', '0040_004.bmp'],
#  ['0040_template', '0040_005.bmp'],
#  ['0040_template', '0040_006.bmp'],
#  ['0040_template', '0040_007.bmp'],
#  ['0040_template', '0040_008.bmp'],
#  ['0040_template', '0040_009.bmp'],
#  ['0040_template', '0040_010.bmp'],
#  ['0040_template', '0040_011.bmp'],
#  ['0040_template', '0040_012.bmp'],
#  ['0040_template', '0040_013.bmp'],
#  ['0040_template', '0040_014.bmp'],
#  ['0040_template', '0040_015.bmp'],
#  ['0040_template', '0040_016.bmp'],
#  ['0040_template', '0040_017.bmp'],
#  ['0040_template', '0040_018.bmp'],
#  ['0040_template', '0040_019.bmp'],
#  ['0041_template', '0041_000.bmp'],
#  ['0041_template', '0041_001.bmp'],
#  ['0041_template', '0041_002.bmp'],
#  ['0041_template', '0041_003.bmp'],
#  ['0041_template', '0041_004.bmp'],
#  ['0041_template', '0041_005.bmp'],
#  ['0041_template', '0041_006.bmp'],
#  ['0041_template', '0041_007.bmp'],
#  ['0041_template', '0041_008.bmp'],
#  ['0041_template', '0041_009.bmp'],
#  ['0041_template', '0041_010.bmp'],
#  ['0041_template', '0041_011.bmp'],
#  ['0041_template', '0041_012.bmp'],
#  ['0041_template', '0041_013.bmp'],
#  ['0041_template', '0041_014.bmp'],
#  ['0041_template', '0041_015.bmp'],
#  ['0041_template', '0041_016.bmp'],
#  ['0041_template', '0041_017.bmp'],
#  ['0041_template', '0041_018.bmp'],
#  ['0041_template', '0041_019.bmp'],
#  ['0042_template', '0042_000.bmp'],
#  ['0042_template', '0042_001.bmp'],
#  ['0042_template', '0042_002.bmp'],
#  ['0042_template', '0042_003.bmp'],
#  ['0042_template', '0042_004.bmp'],
#  ['0042_template', '0042_005.bmp'],
#  ['0042_template', '0042_006.bmp'],
#  ['0042_template', '0042_007.bmp'],
#  ['0042_template', '0042_008.bmp'],
#  ['0042_template', '0042_009.bmp'],
#  ['0042_template', '0042_010.bmp'],
#  ['0042_template', '0042_011.bmp'],
#  ['0042_template', '0042_012.bmp'],
#  ['0042_template', '0042_013.bmp'],
#  ['0042_template', '0042_014.bmp'],
#  ['0042_template', '0042_015.bmp'],
#  ['0042_template', '0042_016.bmp'],
#  ['0042_template', '0042_017.bmp'],
#  ['0042_template', '0042_018.bmp'],
#  ['0042_template', '0042_019.bmp'],
#  ['0043_template', '0043_000.bmp'],
#  ['0043_template', '0043_001.bmp'],
#  ['0043_template', '0043_002.bmp'],
#  ['0043_template', '0043_003.bmp'],
#  ['0043_template', '0043_004.bmp'],
#  ['0043_template', '0043_005.bmp'],
#  ['0043_template', '0043_006.bmp'],
#  ['0043_template', '0043_007.bmp'],
#  ['0043_template', '0043_008.bmp'],
#  ['0043_template', '0043_009.bmp'],
#  ['0043_template', '0043_010.bmp'],
#  ['0043_template', '0043_011.bmp'],
#  ['0043_template', '0043_012.bmp'],
#  ['0043_template', '0043_013.bmp'],
#  ['0043_template', '0043_014.bmp'],
#  ['0043_template', '0043_015.bmp'],
#  ['0043_template', '0043_016.bmp'],
#  ['0043_template', '0043_017.bmp'],
#  ['0043_template', '0043_018.bmp'],
#  ['0043_template', '0043_019.bmp'],
#  ['0044_template', '0044_000.bmp'],
#  ['0044_template', '0044_001.bmp'],
#  ['0044_template', '0044_002.bmp'],
#  ['0044_template', '0044_003.bmp'],
#  ['0044_template', '0044_004.bmp'],
#  ['0044_template', '0044_005.bmp'],
#  ['0044_template', '0044_006.bmp'],
#  ['0044_template', '0044_007.bmp'],
#  ['0044_template', '0044_008.bmp'],
#  ['0044_template', '0044_009.bmp'],
#  ['0044_template', '0044_010.bmp'],
#  ['0044_template', '0044_011.bmp'],
#  ['0044_template', '0044_012.bmp'],
#  ['0044_template', '0044_013.bmp'],
#  ['0044_template', '0044_014.bmp'],
#  ['0044_template', '0044_015.bmp'],
#  ['0044_template', '0044_016.bmp'],
#  ['0044_template', '0044_017.bmp'],
#  ['0044_template', '0044_018.bmp'],
#  ['0044_template', '0044_019.bmp'],
#  ['0045_template', '0045_000.bmp'],
#  ['0045_template', '0045_001.bmp'],
#  ['0045_template', '0045_002.bmp'],
#  ['0045_template', '0045_003.bmp'],
#  ['0045_template', '0045_004.bmp'],
#  ['0045_template', '0045_005.bmp'],
#  ['0045_template', '0045_006.bmp'],
#  ['0045_template', '0045_007.bmp'],
#  ['0045_template', '0045_008.bmp'],
#  ['0045_template', '0045_009.bmp'],
#  ['0045_template', '0045_010.bmp'],
#  ['0045_template', '0045_011.bmp'],
#  ['0045_template', '0045_012.bmp'],
#  ['0045_template', '0045_013.bmp'],
#  ['0045_template', '0045_014.bmp'],
#  ['0045_template', '0045_015.bmp'],
#  ['0045_template', '0045_016.bmp'],
#  ['0045_template', '0045_017.bmp'],
#  ['0045_template', '0045_018.bmp'],
#  ['0045_template', '0045_019.bmp'],
#  ['0046_template', '0046_000.bmp'],
#  ['0046_template', '0046_001.bmp'],
#  ['0046_template', '0046_002.bmp'],
#  ['0046_template', '0046_003.bmp'],
#  ['0046_template', '0046_004.bmp'],
#  ['0046_template', '0046_005.bmp'],
#  ['0046_template', '0046_006.bmp'],
#  ['0046_template', '0046_007.bmp'],
#  ['0046_template', '0046_008.bmp'],
#  ['0046_template', '0046_009.bmp'],
#  ['0046_template', '0046_010.bmp'],
#  ['0046_template', '0046_011.bmp'],
#  ['0046_template', '0046_012.bmp'],
#  ['0046_template', '0046_013.bmp'],
#  ['0046_template', '0046_014.bmp'],
#  ['0046_template', '0046_015.bmp'],
#  ['0046_template', '0046_016.bmp'],
#  ['0046_template', '0046_017.bmp'],
#  ['0046_template', '0046_018.bmp'],
#  ['0046_template', '0046_019.bmp'],
#  ['0047_template', '0047_000.bmp'],
#  ['0047_template', '0047_001.bmp'],
#  ['0047_template', '0047_002.bmp'],
#  ['0047_template', '0047_003.bmp'],
#  ['0047_template', '0047_004.bmp'],
#  ['0047_template', '0047_005.bmp'],
#  ['0047_template', '0047_006.bmp'],
#  ['0047_template', '0047_007.bmp'],
#  ['0047_template', '0047_008.bmp'],
#  ['0047_template', '0047_009.bmp'],
#  ['0047_template', '0047_010.bmp'],
#  ['0047_template', '0047_011.bmp'],
#  ['0047_template', '0047_012.bmp'],
#  ['0047_template', '0047_013.bmp'],
#  ['0047_template', '0047_014.bmp'],
#  ['0047_template', '0047_015.bmp'],
#  ['0047_template', '0047_016.bmp'],
#  ['0047_template', '0047_017.bmp'],
#  ['0047_template', '0047_018.bmp'],
#  ['0047_template', '0047_019.bmp'],
#  ['0048_template', '0048_000.bmp'],
#  ['0048_template', '0048_001.bmp'],
#  ['0048_template', '0048_002.bmp'],
#  ['0048_template', '0048_003.bmp'],
#  ['0048_template', '0048_004.bmp'],
#  ['0048_template', '0048_005.bmp'],
#  ['0048_template', '0048_006.bmp'],
#  ['0048_template', '0048_007.bmp'],
#  ['0048_template', '0048_008.bmp'],
#  ['0048_template', '0048_009.bmp'],
#  ['0048_template', '0048_010.bmp'],
#  ['0048_template', '0048_011.bmp'],
#  ['0048_template', '0048_012.bmp'],
#  ['0048_template', '0048_013.bmp'],
#  ['0048_template', '0048_014.bmp'],
#  ['0048_template', '0048_015.bmp'],
#  ['0048_template', '0048_016.bmp'],
#  ['0048_template', '0048_017.bmp'],
#  ['0048_template', '0048_018.bmp'],
#  ['0048_template', '0048_019.bmp'],
#  ['0049_template', '0049_000.bmp'],
#  ['0049_template', '0049_001.bmp'],
#  ['0049_template', '0049_002.bmp'],
#  ['0049_template', '0049_003.bmp'],
#  ['0049_template', '0049_004.bmp'],
#  ['0049_template', '0049_005.bmp'],
#  ['0049_template', '0049_006.bmp'],
#  ['0049_template', '0049_007.bmp'],
#  ['0049_template', '0049_008.bmp'],
#  ['0049_template', '0049_009.bmp'],
#  ['0049_template', '0049_010.bmp'],
#  ['0049_template', '0049_011.bmp'],
#  ['0049_template', '0049_012.bmp'],
#  ['0049_template', '0049_013.bmp'],
#  ['0049_template', '0049_014.bmp'],
#  ['0049_template', '0049_015.bmp'],
#  ['0049_template', '0049_016.bmp'],
#  ['0049_template', '0049_017.bmp'],
#  ['0049_template', '0049_018.bmp'],
#  ['0049_template', '0049_019.bmp'],
#  ...]

# %% [markdown]
# # Get Flattened Data

# %% [markdown]
# ## Single-Thread

# %%
total_time_using = 0
# df_calculate_total_time_using = 0

tem1_path = 'C:\\Users\\Sabig\\Iris\\shifting example\\Iris-Dataset\\CASIA-IrisV2\\device2\\0023_template\\0023_000.bmp'
tem1 = cv2.imread(tem1_path, cv2.IMREAD_GRAYSCALE)
for i, template in enumerate(all_template_index):
    start_t = time.time()
    tem2 = cv2.imread(os.path.join(dataset_path, template[0],template[1]), cv2.IMREAD_GRAYSCALE)
    hd_df = HammingDistance(template1=tem1, template2=tem2)
    jc_df = jaccard_distance_shifted(template1=tem1, template2=tem2)
    ps_df = pearson_correlation_shifted(template1=tem1, template2=tem2)
    flattened_data = pd.DataFrame([item for sublist in [hd_df[1], jc_df, ps_df] for item in sublist]).T
    total_time_using += time.time() - start_t

print("total time using:", total_time_using,"sec")
print(f"average: {(total_time_using/len(all_template_index))*1000} ms/compare")
print(f"total data compare {len(all_template_index)} times")
flattened_data
# Out:
# total time using: 42.09938335418701 sec
# average: 35.08281946182251 ms/compare
# total data compare 1200 times
#          0         1         2         3         4         5         6   \
# 0  0.499238  0.500547  0.502441  0.503418  0.502188  0.498477  0.494102
#
#          7         8         9   ...        41        42        43        44  \
# 0  0.493301  0.506211  0.497344  ...  0.013321 -0.012507  0.005229  0.016246
#
#         45        46        47        48        49        50
# 0  0.02195  0.024606  0.021559  0.013121 -0.003444 -0.021102
#
# [1 rows x 51 columns]

# %% [markdown]
# ## Multi-Thread

# %%
from multiprocessing import Pool, cpu_count
import cv2

def get_flattened_mp(batch):
    print("in func")
    print(batch)

if __name__ == "__main__":
    total_time_using = 0

    tem1_path = 'C:\\Users\\Sabig\\Iris\\shifting example\\Iris-Dataset\\CASIA-IrisV2\\device2\\0023_template\\0023_000.bmp'
    tem1 = cv2.imread(tem1_path, cv2.IMREAD_GRAYSCALE)

    num_threads = 4
    batch_size = len(all_template_index)//num_threads
    print("batching")
    batches = [all_template_index[i:i + batch_size] for i in range(0, len(all_template_index), batch_size)]

    start_t = time.time()
    with Pool(processes=num_threads) as pool:
        print("in pool")
        all_result = pool.map(get_flattened_mp, batches)

    print("total time using:", total_time_using,"sec")
    print(f"average: {(total_time_using/len(all_template_index))*1000} ms/compare")
    print(f"total data compare {len(all_template_index)} times")
# Out:
# batching
# in pool
